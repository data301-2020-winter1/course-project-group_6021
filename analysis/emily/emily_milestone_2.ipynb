# %% [markdown]
# **Emily Milestone 2**

# %%
import pandas as pd
import numpy as np
from numpy import nan as NA
import seaborn as sns
import matplotlib.pyplot as plt



data  = pd.read_csv("../../data/raw/day.csv")
print(data.count())
# Out:
# instant       731
# dteday        731
# season        731
# yr            731
# mnth          731
# holiday       731
# weekday       731
# workingday    731
# weathersit    731
# temp          731
# atemp         731
# hum           731
# windspeed     731
# casual        731
# registered    731
# cnt           731
# dtype: int64

# %%
data.head(5)
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
import sys, os

# %%
import sys, os
sys.path.insert(0, os.path.abspath('analysis/emily/project_functions.py'))
from scripts.project_functions import *

# %%
data_eda= load_and_process("../../data/raw/day.csv")

# %%
data_eda
# Out:
#            Date  season  Year  mnth  holiday  weekday  workingday  weathersit  \
# 0    2011-01-01       1     0     1        0        6           0           2
# 1    2011-01-02       1     0     1        0        0           0           2
# 2    2011-01-03       1     0     1        0        1           1           1
# 3    2011-01-04       1     0     1        0        2           1           1
# 4    2011-01-05       1     0     1        0        3           1           1
# ..          ...     ...   ...   ...      ...      ...         ...         ...
# 726  2012-12-27       1     1    12        0        4           1           2
# 727  2012-12-28       1     1    12        0        5           1           2
# 728  2012-12-29       1     1    12        0        6           0           2
# 729  2012-12-30       1     1    12        0        0           0           1
# 730  2012-12-31       1     1    12        0        1           1           2
#
# ...

# %%
#Emily's Exploratory Data Analysis(EDA)

# %%
data_eda.head()
# Out:
#          Date  season  Year  mnth  holiday  weekday  workingday  weathersit  \
# 0  2011-01-01       1     0     1        0        6           0           2
# 1  2011-01-02       1     0     1        0        0           0           2
# 2  2011-01-03       1     0     1        0        1           1           1
# 3  2011-01-04       1     0     1        0        2           1           1
# 4  2011-01-05       1     0     1        0        3           1           1
#
#        temp     atemp       hum  windspeed  casual  registered  Total  \
# 0  0.344167  0.363625  0.805833   0.160446     331         654    985
# 1  0.363478  0.353739  0.696087   0.248539     131         670    801
# 2  0.196364  0.189405  0.437273   0.248309     120        1229   1349
# 3  0.200000  0.212122  0.590435   0.160296     108        1454   1562
# 4  0.226957  0.229270  0.436957   0.186900      82        1518   1600
#
#       Ratio
# 0  0.506116
# 1  0.195522
# 2  0.097640
# 3  0.074278
# 4  0.054018

# %%
#descriptive statistics of the data

# %%
data_eda.describe()
# Out:
#            season        Year        mnth     holiday     weekday  workingday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     2.496580    0.500684    6.519836    0.028728    2.997264    0.683995
# std      1.110807    0.500342    3.451913    0.167155    2.004787    0.465233
# min      1.000000    0.000000    1.000000    0.000000    0.000000    0.000000
# 25%      2.000000    0.000000    4.000000    0.000000    1.000000    0.000000
# 50%      3.000000    1.000000    7.000000    0.000000    3.000000    1.000000
# 75%      3.000000    1.000000   10.000000    0.000000    5.000000    1.000000
# max      4.000000    1.000000   12.000000    1.000000    6.000000    1.000000
#
#        weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     1.395349    0.495385    0.474354    0.627894    0.190486
# std      0.544894    0.183051    0.162961    0.142429    0.077498
# ...

# %%
#number of rows by number of columns
data_eda.shape
# Out:
# (731, 16)

# %%
#Name of each column
data_eda.columns
# Out:
# Index(['Date', 'season', 'Year', 'mnth', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'Total', 'Ratio'],
#       dtype='object')

# %%
#number of unique values for each variable
data_eda.nunique(axis=0)
# Out:
# Date          731
# season          4
# Year            2
# mnth           12
# holiday         2
# weekday         7
# workingday      2
# weathersit      3
# temp          499
# atemp         690
# hum           595
# windspeed     650
# casual        606
# registered    679
# Total         696
# Ratio         729
# dtype: int64

# %%
#ensuring the data is cleaned properly by looking to see if the NA values were removed with the code abve
data_eda.isnull().values.any()
# Out:
# False

# %%
#Analyzing relationships between vaitables 
corr = data_eda.corr()
sns.heatmap(corr, xticklabels = corr.columns, yticklabels=corr.columns, annot = True,  fmt='.1g', cmap=sns.diverging_palette(220,20,as_cmap=True))

plt.figure(figsize=(12, 9))

sns.heatmap(data_eda)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-638260e3d111> in <module>
#       5 plt.figure(figsize=(12, 9))
#       6
# ----> 7 sns.heatmap(data_eda)
#
# ~/opt/miniconda3/lib/python3.8/site-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~/opt/miniconda3/lib/python3.8/site-packages/seaborn/matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     543     """
#     544     # Initialize the plotter object
# --> 545     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
# ...

# %%
#comparing registered and casual users based on the temperature 
data_eda.plot(kind = 'scatter', x = 'registered', y = 'temp')
# Out:
# <AxesSubplot:xlabel='registered', ylabel='temp'>

# %%
data_eda.plot(kind = 'scatter', x = 'casual', y = 'temp')
# Out:
# <AxesSubplot:xlabel='casual', ylabel='temp'>

# %%
data_eda.plot(kind = 'histogram', x = 'year', y = 'total')

# %%
sns.pairplot(data_eda)#not sure why this didnt work. Type of variables?
