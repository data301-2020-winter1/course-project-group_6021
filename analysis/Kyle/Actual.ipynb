# %%
import pandas as pd
import numpy as np
import seaborn as sns
from functions import *

df  = pd.read_csv("../../data/raw/day.csv")

# %%
df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp     atemp       hum  windspeed  casual  registered  \
# ...

# %%
df2 = load_and_process("../../data/raw/day.csv")
df2
# Out:
#            Date  season  Year  Month  holiday  weekday  workingday  \
# 0    2011-01-01       1     0      1        0        6           0
# 1    2011-01-02       1     0      1        0        0           0
# 2    2011-01-03       1     0      1        0        1           1
# 3    2011-01-04       1     0      1        0        2           1
# 4    2011-01-05       1     0      1        0        3           1
# ..          ...     ...   ...    ...      ...      ...         ...
# 726  2012-12-27       1     1     12        0        4           1
# 727  2012-12-28       1     1     12        0        5           1
# 728  2012-12-29       1     1     12        0        6           0
# 729  2012-12-30       1     1     12        0        0           0
# 730  2012-12-31       1     1     12        0        1           1
#
#      WeatherSituation      temp     atemp       hum  windspeed  casual  \
# 0                   2  0.344167  0.363625  0.805833   0.160446     331
# ...

# %%
df11 = ten_pop_days_eleven("../../data/raw/day.csv")
df11
# Out:
#      Month        Date  Total
# 0        1  2011-01-01    985
# 1        1  2011-01-02    801
# 2        1  2011-01-03   1349
# 3        1  2011-01-04   1562
# 4        1  2011-01-05   1600
# ..     ...         ...    ...
# 360     12  2011-12-27   1162
# 361     12  2011-12-28   2302
# 362     12  2011-12-29   2423
# 363     12  2011-12-30   2999
# 364     12  2011-12-31   2485
#
# [365 rows x 3 columns]

# %%
df12 = ten_pop_days_twelve("../../data/raw/day.csv")
df12
# Out:
#      Month        Date  Total
# 365      1  2012-01-01   2294
# 366      1  2012-01-02   1951
# 367      1  2012-01-03   2236
# 368      1  2012-01-04   2368
# 369      1  2012-01-05   3272
# ..     ...         ...    ...
# 726     12  2012-12-27   2114
# 727     12  2012-12-28   3095
# 728     12  2012-12-29   1341
# 729     12  2012-12-30   1796
# 730     12  2012-12-31   2729
#
# [366 rows x 3 columns]

# %%
dfeleven = tpd_eleven("../../data/raw/day.csv")
dfeleven
# Out:
#      Month        Date  Total
# 184      7  2011-07-04   6043
# 196      7  2011-07-16   5923
# 234      8  2011-08-23   5895
# 140      5  2011-05-21   5805
# 195      7  2011-07-15   5538
# ..     ...         ...    ...
# 301     10  2011-10-29    627
# 68       3  2011-03-10    623
# 64       3  2011-03-06    605
# 25       1  2011-01-26    506
# 26       1  2011-01-27    431
#
# [365 rows x 3 columns]

# %%
dftwelve = tpd_twelve("../../data/raw/day.csv")
dftwelve
# Out:
#      Month        Date  Total
# 623      9  2012-09-15   8714
# 637      9  2012-09-29   8555
# 630      9  2012-09-22   8395
# 447      3  2012-03-23   8362
# 504      5  2012-05-19   8294
# ..     ...         ...    ...
# 477      4  2012-04-22   1027
# 724     12  2012-12-25   1013
# 723     12  2012-12-24    920
# 725     12  2012-12-26    441
# 667     10  2012-10-29     22
#
# [366 rows x 3 columns]

# %%
##QUESTION 1

# %%
df4 = tpd("../../data/raw/day.csv")
print(df4)
# Out:
#      Month        Date  Total
# 623      9  2012-09-15   8714
# 637      9  2012-09-29   8555
# 630      9  2012-09-22   8395
# 447      3  2012-03-23   8362
# 504      5  2012-05-19   8294
# ..     ...         ...    ...
# 477      4  2012-04-22   1027
# 724     12  2012-12-25   1013
# 723     12  2012-12-24    920
# 725     12  2012-12-26    441
# 667     10  2012-10-29     22
#
# [366 rows x 3 columns]

# %%
sns.displot(data=df4.head(50), x='Month', y='Total')

# %%
sns.displot(df4, x = df4['Total'], y='Month', hue = "Month")

# %%
##QUESTION 3

# %%
sns.set_theme(style='whitegrid')
sns.relplot(x='weathersit',y='Total',data=df2)

# %%
##QUESTION 4

# %%
df6 = df2[df2["workingday"] == 1]

sns.relplot(x='weekday',y='casual',data=df6)
sns.relplot(x='weekday',y='registered',data=df6)

# %%
##QUESTION 4 WEEKEND/HOLIDAYS

# %%
df5 = df2[df2["workingday"] == 0]

sns.relplot(x='weekday',y='casual',data=df5)
sns.relplot(x='weekday',y='registered',data=df5)

# %%
##QUESTION 5 2011 COMPARED TO 2012

# %%
elevenTotal = 0

for row in dfeleven.iterrows():
    elevenTotal += dfeleven['Total']
    
print(elevenTotal)
# Out:
# 184    2205695
# 196    2161895
# 234    2151675
# 140    2118825
# 195    2021370
#         ...
# 301     228855
# 68      227395
# 64      220825
# 25      184690
# 26      157315
# Name: Total, Length: 365, dtype: int64

# %%
sumEleven = dfeleven['Total'].sum(axis = 0)
sumTwelve = dftwelve['Total'].sum(axis = 0)

# %%
print(sumEleven)
print(sumTwelve)
# Out:
# 1243103
# 2049576
