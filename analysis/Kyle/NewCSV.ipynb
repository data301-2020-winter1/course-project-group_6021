# %%
import pandas as pd
import numpy as np
import seaborn as sns
from functions import *

# %%
df = newT("../../data/raw/day.csv")

df
# Out:
#            Date  Year Month Holiday Weekday WorkingDay WeatherSituation  \
# 0    2011-01-01  2011   Jan   False     Sat      False           Cloudy
# 1    2011-01-02  2011   Jan   False     Sun      False           Cloudy
# 2    2011-01-03  2011   Jan   False     Mon       True            Sunny
# 3    2011-01-04  2011   Jan   False    Tues       True            Sunny
# 4    2011-01-05  2011   Jan   False     Wed       True            Sunny
# ..          ...   ...   ...     ...     ...        ...              ...
# 726  2012-12-27  2012   Dec   False    Thur       True           Cloudy
# 727  2012-12-28  2012   Dec   False     Fri       True           Cloudy
# 728  2012-12-29  2012   Dec   False     Sat      False           Cloudy
# 729  2012-12-30  2012   Dec   False     Sun      False            Sunny
# 730  2012-12-31  2012   Dec   False     Mon       True           Cloudy
#
#      Casual  Registered  Total
# 0       331         654    985
# 1       131         670    801
# ...

# %%
df.to_csv("../../data/processed/tableau.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-3-b56c88b52d74> in <module>
# ----> 1 df.to_csv("../../data/processed")
#
# D:\Python_MC\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3168             decimal=decimal,
#    3169         )
# -> 3170         formatter.save()
#    3171
#    3172         if path_or_buf is None:
#
# D:\Python_MC\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     183             close = False
#     184         else:
# --> 185             f, handles = get_handle(
#     186                 self.path_or_buf,
#     187                 self.mode,
#
# ...
