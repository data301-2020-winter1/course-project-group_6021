# %% [markdown]
# # Condut EDA

# %% [markdown]
# ## Import necessary functions for analysis

# %%
from Scripts.project_functions import *

# %% [markdown]
# ### Load and then process the data

# %%
df = load_and_process('../../data/raw/day.csv')

# %% [markdown]
# #### Perform *Exploratory Data Analysis* for both categorical and numerical data

# %%
eda(df)
# Out:
# Preview of data:
#          Date  Season  Year Month  Holiday weekday  workingday  \
# 0  2011-01-01  Winter     0   Jan        0     Sat           0
# 1  2011-01-02  Winter     0   Jan        0     Sun           0
# 2  2011-01-03  Winter     0   Jan        0     Mon           1
# 3  2011-01-04  Winter     0   Jan        0    Tues           1
# 4  2011-01-05  Winter     0   Jan        0     Wed           1
# 5  2011-01-06  Winter     0   Jan        0    Thur           1
# 6  2011-01-07  Winter     0   Jan        0     Fri           1
# 7  2011-01-08  Winter     0   Jan        0     Sat           0
# 8  2011-01-09  Winter     0   Jan        0     Sun           0
# 9  2011-01-10  Winter     0   Jan        0     Mon           1
#
#   Weather Situation  Temperature  Humidity  Windspeed  casual  registered  \
# 0            Cloudy     0.344167  0.805833   0.160446     331         654
# 1            Cloudy     0.363478  0.696087   0.248539     131         670
# ...

# %% [markdown]
# # Some observations from the EDA above:
# * The data overall is distributed all over the place with some slight skewness.
# * Of all 3 weather situations, sunny takes up most of the data.
# * There are obvious outlier so that doesn't affect the data in general.
#
# **There are some clear correlation between weather with the total number of riders, especially in windy weather.**
