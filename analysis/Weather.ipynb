# %%
from Hugh.Scripts.project_functions import *

# %% [markdown]
# # Weather data and total number of riders through out the year

# %%
weather = weatheronly("../data/raw/day.csv")
weather
# Out:
#     Weather Situation  Temperature  Humidity  Windspeed  Total
# 0              Cloudy     0.344167  0.805833   0.160446    985
# 1              Cloudy     0.363478  0.696087   0.248539    801
# 2               Sunny     0.196364  0.437273   0.248309   1349
# 3               Sunny     0.200000  0.590435   0.160296   1562
# 4               Sunny     0.226957  0.436957   0.186900   1600
# ..                ...          ...       ...        ...    ...
# 726            Cloudy     0.254167  0.652917   0.350133   2114
# 727            Cloudy     0.253333  0.590000   0.155471   3095
# 728            Cloudy     0.253333  0.752917   0.124383   1341
# 729             Sunny     0.255833  0.483333   0.350754   1796
# 730            Cloudy     0.215833  0.577500   0.154846   2729
#
# [731 rows x 5 columns]

# %% [markdown]
# # Correlation map between temperature, humidity, windspeed

# %%
sns.heatmap(weather.corr())
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(weather)

# %% [markdown]
# # Scatterplot between windspeed and number of riders

# %%
sns.relplot(x='Windspeed',y='Total',data=weather,hue = 'Windspeed')

# %%
g = sns.PairGrid(weather, vars=["Windspeed", "Total"], hue="Weather Situation")
g.map(sns.scatterplot)

# %%
g = sns.PairGrid(weather)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(sns.kdeplot, lw=3, legend=False)

# %%
g = sns.PairGrid(weather, vars=["Weather Situation", "Total"], hue="Weather Situation")
g.map(sns.scatterplot)
